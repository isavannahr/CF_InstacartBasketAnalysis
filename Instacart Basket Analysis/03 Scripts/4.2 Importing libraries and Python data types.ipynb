# %% [markdown]
# # 01. Importing Libaries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Data Types

# %%
# Code 3 different ways of reaching the result of 100 
97 + 3
# Out:
# 100

# %%
50 * 2
# Out:
# 100

# %%
150 - 50
# Out:
# 100

# %%
# Code 2 floating-point variables and divide them by each other 
54.3/0.3
# Out:
# 181.0

# %%
#Construct a short word made of seperate strings.
word1 = 'Be '
word2 = 'Positive'
word1 + word2
# Out:
# 'Be Positive'

# %%
#Construct 2 short sentences made of two seperate strings
sent1 = 'Doing schoolwork is very productive. '
sent2 = 'I highly recommend it.' 
sent1 + sent2
# Out:
# 'Doing schoolwork is very productive. I highly recommend it.'
