# %% [markdown]
# # 01 Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 Import Data

# %%
path = r'C:\Users\isava\OneDrive\Documents\CareerFoundry\Data Immersion\PythonFundamentals\Instacart Basket Analysis'
path
# Out:
# 'C:\\Users\\isava\\OneDrive\\Documents\\CareerFoundry\\Data Immersion\\PythonFundamentals\\Instacart Basket Analysis'

# %%
df_ords_prods = pd.read_pickle(os.path.join(path,'02 Data', 'Prepared Data','orders_products_combined.pkl'))
df_prods = pd.read_csv(os.path.join(path,'02 Data', 'Prepared Data','products_checked.csv'), index_col = False)

# %%
df_ords_prods.shape
# Out:
# (32434489, 10)

# %% [markdown]
# ### Save Memory

# %%
df_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49672 entries, 0 to 49671
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     49672 non-null  int64
#  1   product_id     49672 non-null  int64
#  2   product_name   49672 non-null  object
#  3   aisle_id       49672 non-null  int64
#  4   department_id  49672 non-null  int64
#  5   prices         49672 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.3+ MB

# %%
# Further columns from other data sets
df_prods.drop(columns = {'Unnamed: 0'}, inplace = True)

# %%
df_prods['aisle_id'] = df_prods['aisle_id'].astype('int8')

# %%
df_prods['department_id'] = df_prods['department_id'].astype('int8')
#df_prods['prices'] = df_prods['prices'].astype('float16') this creates inf variables that we dont want

# %%
df_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49672 entries, 0 to 49671
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49672 non-null  int64
#  1   product_name   49672 non-null  object
#  2   aisle_id       49672 non-null  int8
#  3   department_id  49672 non-null  int8
#  4   prices         49672 non-null  float64
# dtypes: float64(1), int64(1), int8(2), object(1)
# memory usage: 1.2+ MB

# %% [markdown]
# # 03 Merging Data

# %%
df_ords_prods.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_users_prior_order  product_id  add_to_cart_order  reordered  \
# 0                           NaN         196                  1          0
# 1                           NaN       14084                  2          0
# 2                           NaN       12427                  3          0
# 3                           NaN       26088                  4          0
# 4                           NaN       26405                  5          0
#
#   _merge
# 0   both
# 1   both
# 2   both
# 3   both
# 4   both

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# We can merge on product id.

# %%
df_merged_large = df_ords_prods.merge(df_prods, on = 'product_id', indicator = '_prodMerge') #Indicator throwing error because there cannot be two columns names _Merge so I created a custom one here

# %%
df_merged_large['_prodMerge'].value_counts()
# Out:
# _prodMerge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# The resulting dataframe has 32,404,859 rows.

# %% [markdown]
# # 04 Export Data Frame

# %%
#df_merged_large.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.csv'))
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
